# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("canada_per_capita_income.csv")

# %%
df.shape
# Out:
# (47, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     47 non-null     int64
#  1   per capita income (US$)  47 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 880.0 bytes

# %%
df.ndim
# Out:
# 2

# %%
df.head(n=10)
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583
# 5  1975              5998.144346
# 6  1976              7062.131392
# 7  1977              7100.126170
# 8  1978              7247.967035
# 9  1979              7602.912681

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('Per Capita Income')
plt.scatter(df.year, df['per capita income (US$)'], color='red', marker = '+')

# %%
income_df = df.drop('year', axis = 'columns')

# %%
income_df.head(n=10)
# Out:
#    per capita income (US$)
# 0              3399.299037
# 1              3768.297935
# 2              4251.175484
# 3              4804.463248
# 4              5576.514583
# 5              5998.144346
# 6              7062.131392
# 7              7100.126170
# 8              7247.967035
# 9              7602.912681

# %%
year_df = df.drop('per capita income (US$)',axis = 'columns')

# %%
year_df.tail(n=10)
# Out:
#     year
# 37  2007
# 38  2008
# 39  2009
# 40  2010
# 41  2011
# 42  2012
# 43  2013
# 44  2014
# 45  2015
# 46  2016

# %%
model = linear_model.LinearRegression()

# %%
trained_model = model.fit(year_df, income_df)

# %%
trained_model
# Out:
# LinearRegression()

# %%
trained_model.predict([[2020]])
# Out:
# /home/ahmedunix/.cache/pypoetry/virtualenvs/data-science-work-mqn9WFvk-py3.10/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41288.69409442]])

# %%
trained_model.coef_
# Out:
# array([[828.46507522]])

# %%
trained_model.intercept_
# Out:
# array([-1632210.75785546])
